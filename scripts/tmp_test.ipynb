# %%
get_ipython().magic('matplotlib inline')
get_ipython().magic('reload_ext autoreload')
get_ipython().magic('autoreload 2')

# %matplotlib inline
from commercial_search import *

test_single_video('MSNBCW_20150115_020000_The_Rachel_Maddow_Show')
